# %% [markdown]
# # TP3
# par Skander Meziou

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import networkx as nx
import matplotlib.pyplot as plt

# Load the REBEL model
model_name = "Babelscape/rebel-large"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# The text to process
text = """
Harry Potter and the Prisoner of Azkaban is a 2004 fantasy film directed by Alfonso Cuarón from a screenplay by Steve Kloves. It is based on the 1999 novel Harry Potter and the Prisoner of Azkaban by J. K. Rowling. It is the sequel to Harry Potter and the Chamber of Secrets (2002) and the third instalment in the Harry Potter film series. The film stars Daniel Radcliffe as Harry Potter, alongside Rupert Grint and Emma Watson as Harry's best friends Ron Weasley and Hermione Granger respectively. It chronicles Harry's third year at Hogwarts and his quest to uncover the truth about his past, including the connection recently-escaped Azkaban prisoner Sirius Black has to Harry and his deceased parents.

With this film, the Harry Potter series switched to a longer eighteen-month production cycle. Cuarón was selected as director from a list that included Callie Khouri and Kenneth Branagh. The cast of previous instalments returned for the film, with the additions of Gary Oldman, David Thewlis, Timothy Spall, and Emma Thompson, among others. It was the first appearance of Michael Gambon as Professor Albus Dumbledore, due to Richard Harris's death in 2002. Principal photography began in February 2003 at Leavesden Film Studios. It was the first in the series to extensively use real-life locations, with sets built in Scotland and scenes shot in London. Filming wrapped in November 2003.

The film was released on 31 May 2004 in the United Kingdom, and on 4 June 2004 in North America. It was the first Harry Potter film to use IMAX Technology and released into IMAX theatres. Prisoner of Azkaban grossed a total of $808 million worldwide, making it the second-highest-grossing film of 2004, behind Shrek 2. Critics praised Cuarón's direction and the lead actors' performances. It is credited for marking a notable shift in the franchise's tone and directing style and is often regarded by critics and fans alike as the best Harry Potter film. It was nominated for two Academy Awards, Best Original Music Score and Best Visual Effects, at the 77th Academy Awards in 2004. It was followed by Harry Potter and the Goblet of Fire in 2005. 
"""
#pour etre sur de pas depasser le nombre de token
def split_text(text, max_length=512):
    """Split text into blocks of manageable length"""
    sentences = text.split(". ")
    blocks = []
    current_block = ""
    for sentence in sentences:
        if len(current_block) + len(sentence) <= max_length:
            current_block += sentence + ". "
        else:
            blocks.append(current_block.strip())
            current_block = sentence + ". "
    if current_block:
        blocks.append(current_block.strip())
    return blocks

def extract_entities_and_relations(block):
    """Extract entities and relations from a text block"""
    inputs = tokenizer(block, return_tensors="pt", truncation=True, max_length=512)
    outputs = model.generate(**inputs)
    decoded_output = tokenizer.batch_decode(outputs, skip_special_tokens=True)
    print(f"Raw extraction output: {decoded_output[0]}")
    return decoded_output[0]

def parse_rebel_output(output):
    """Parse the REBEL model output into triples"""
    triples = []
    statements = output.split('\n')
    for statement in statements:
        parts = statement.split('  ')
        if len(parts) >= 3:
            subject = parts[0].strip()
            obj = parts[1].strip()
            relation = parts[2].strip()
            if subject and obj and relation:
                triples.append((subject, relation, obj))
    return triples

def create_graph(triples):
    """Create a NetworkX graph from triples"""
    graph = nx.DiGraph()
    for triple in triples:
        print(f"Triple: {triple}")
        if len(triple) == 3 and all(triple):
            subject, relation, obj = triple
            graph.add_node(subject)
            graph.add_node(obj)
            graph.add_edge(subject, obj, label=relation)

    return graph

def plot_graph(graph):
    """Visualize the knowledge graph"""
    plt.figure(figsize=(12,8))
    if len(graph) == 0:
        print("Warning: Graph is empty!")
        return
    pos = nx.kamada_kawai_layout(graph)
    nx.draw_networkx_nodes(graph, pos, node_color="lightblue", node_size=3000)
    nx.draw_networkx_labels(graph, pos, font_size=10, font_weight="bold")
    nx.draw_networkx_edges(graph, pos)
    edge_labels = nx.get_edge_attributes(graph, 'label')
    nx.draw_networkx_edge_labels(graph, pos, edge_labels=edge_labels)

    plt.title("Knowledge Graph")
    plt.axis('off')
    plt.tight_layout()
    plt.show()

text_blocks = split_text(text)

triples = []
for block in text_blocks:
    result = extract_entities_and_relations(block)
    block_triples = parse_rebel_output(result)
    triples.extend(block_triples)

print("\nExtracted Triples:")
for triple in triples:
    print(triple)

knowledge_graph = create_graph(triples)
plot_graph(knowledge_graph)
# Out:
# Raw extraction output:  Harry Potter and the Prisoner of Azkaban  2004  publication date  fantasy film  genre  Alfonso Cuarón  director  Steve Kloves  screenwriter  Harry Potter film series  part of the series  Harry Potter and the Chamber of Secrets  fantasy film  genre  Alfonso Cuarón  director  Harry Potter film series  part of the series  Harry Potter film series  Harry Potter and the Prisoner of Azkaban  has part  Harry Potter and the Chamber of Secrets
# Raw extraction output:  Sirius Black  Azkaban  residence
# Raw extraction output:  Professor Albus Dumbledore  Michael Gambon  performer
# Raw extraction output:  Prisoner of Azkaban  31 May 2004  publication date
# Raw extraction output:  Best Original Music Score  Academy Awards  instance of  Best Visual Effects  Academy Awards  instance of
#
# Extracted Triples:
# ('Harry Potter and the Prisoner of Azkaban', 'publication date', '2004')
# ('Sirius Black', 'residence', 'Azkaban')
# ('Professor Albus Dumbledore', 'performer', 'Michael Gambon')
# ('Prisoner of Azkaban', 'publication date', '31 May 2004')
# ('Best Original Music Score', 'instance of', 'Academy Awards')
# Triple: ('Harry Potter and the Prisoner of Azkaban', 'publication date', '2004')
# Triple: ('Sirius Black', 'residence', 'Azkaban')
# Triple: ('Professor Albus Dumbledore', 'performer', 'Michael Gambon')
# Triple: ('Prisoner of Azkaban', 'publication date', '31 May 2004')
# Triple: ('Best Original Music Score', 'instance of', 'Academy Awards')

# %%
import requests
import re

def get_wikipedia_summary(title, year=-1, language="en"):
    """
    Récupère le résumé d'un article Wikipédia ou sélectionne une sous-page pertinente.
    :param title: Titre de la page Wikipédia.
    :param year: Année associée au film (par défaut -1 pour ignorer).
    :param language: Langue de l'article (par défaut "en").
    :return: Résumé textuel de l'article.
    """
    url = f"https://{language}.wikipedia.org/w/api.php"
    params = {
        "action": "query",
        "format": "json",
        "titles": title,
        "prop": "extracts",
        "explaintext": True,
        "redirects": 1  # Suivre les redirections
    }

    response = requests.get(url, params=params)
    if response.status_code == 200:
        data = response.json()
        page = next(iter(data["query"]["pages"].values()))

        # Cas où la page contient "may refer to"
        if "extract" in page and "may refer to" in page["extract"]:
            # Extraire les sous-pages mentionnées dans la section
            subpages = re.findall(r"(?<=\n)Frozen \((.*?)\)", page["extract"])
            if year != -1:
                # Filtrer les sous-pages contenant l'année
                matching_pages = [sp for sp in subpages if str(year) in sp]
                if matching_pages:
                    print(f"Correspondance trouvée : Frozen ({matching_pages[0]})")
                    return get_wikipedia_summary(f"Frozen ({matching_pages[0]})", language=language)
            # Si aucune correspondance avec l'année, choisir la première sous-page
            if subpages:
                print(f"Aucune année précise trouvée. Sélection de : Frozen ({subpages[0]})")
                return get_wikipedia_summary(f"Frozen ({subpages[0]})", language=language)
            else:
                print("Aucune sous-page identifiable.")
                return None

        # Retourner le résumé de la page normale
        if "extract" in page:
            return page["extract"]
        else:
            print(f"Aucun résumé trouvé pour le titre '{title}'.")
            return None
    else:
        print(f"Erreur lors de la requête : {response.status_code}")
        return None


# Exemple d'utilisation
summary = get_wikipedia_summary("Frozen", year=2013, language="en")
if summary:
    print(f"Résumé de la page sélectionnée :\n{summary[:500]}...")  # Affiche les 500 premiers caractères
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 99
#      96 triples = []
#      98 for block in text_blocks:
# ---> 99     result = extract_entities_and_relations(block)
#     100     block_triples = parse_rebel_output(result)
#     101     triples.extend(block_triples)
#
# Cell In[35], line 31, in extract_entities_and_relations(block)
#      29 def extract_entities_and_relations(block):
#      30     inputs = tokenizer(block, return_tensors="pt", truncation=True, max_length=512)
# ---> 31     outputs = model.generate(**inputs)
#      32     decoded_output = tokenizer.batch_decode(outputs, skip_special_tokens=True)
#      33     print(f"Raw extraction output: {decoded_output[0]}")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\generation\utils.py:2283, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2275     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2276         input_ids=input_ids,
#    2277         expand_size=generation_config.num_beams,
#    2278         is_encoder_decoder=self.config.is_encoder_decoder,
#    2279         **model_kwargs,
#    2280     )
#    2282     # 13. run beam sample
# -> 2283     result = self._beam_search(
#    2284         input_ids,
#    2285         beam_scorer,
#    2286         logits_processor=prepared_logits_processor,
#    2287         stopping_criteria=prepared_stopping_criteria,
#    2288         generation_config=generation_config,
#    2289         synced_gpus=synced_gpus,
#    2290         **model_kwargs,
#    2291     )
#    2293 elif generation_mode == GenerationMode.GROUP_BEAM_SEARCH:
#    2294     # 11. prepare beam search scorer
#    2295     beam_scorer = BeamSearchScorer(
#    2296         batch_size=batch_size,
#    2297         num_beams=generation_config.num_beams,
#    (...)
#    2303         max_length=generation_config.max_length,
#    2304     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\generation\utils.py:3503, in GenerationMixin._beam_search(self, input_ids, beam_scorer, logits_processor, stopping_criteria, generation_config, synced_gpus, **model_kwargs)
#    3500     outputs = stack_model_outputs(outputs_per_sub_batch, self.config.get_text_config())
#    3502 else:  # Unchanged original behavior
# -> 3503     outputs = self(**model_inputs, return_dict=True)
#    3505 # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#    3506 model_kwargs = self._update_model_kwargs_for_generation(
#    3507     outputs,
#    3508     model_kwargs,
#    3509     is_encoder_decoder=self.config.is_encoder_decoder,
#    3510 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\models\bart\modeling_bart.py:1642, in BartForConditionalGeneration.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1637     if decoder_input_ids is None and decoder_inputs_embeds is None:
#    1638         decoder_input_ids = shift_tokens_right(
#    1639             labels, self.config.pad_token_id, self.config.decoder_start_token_id
#    1640         )
# -> 1642 outputs = self.model(
#    1643     input_ids,
#    1644     attention_mask=attention_mask,
#    1645     decoder_input_ids=decoder_input_ids,
#    1646     encoder_outputs=encoder_outputs,
#    1647     decoder_attention_mask=decoder_attention_mask,
#    1648     head_mask=head_mask,
#    1649     decoder_head_mask=decoder_head_mask,
#    1650     cross_attn_head_mask=cross_attn_head_mask,
#    1651     past_key_values=past_key_values,
#    1652     inputs_embeds=inputs_embeds,
#    1653     decoder_inputs_embeds=decoder_inputs_embeds,
#    1654     use_cache=use_cache,
#    1655     output_attentions=output_attentions,
#    1656     output_hidden_states=output_hidden_states,
#    1657     return_dict=return_dict,
#    1658 )
#    1660 lm_logits = self.lm_head(outputs[0])
#    1661 lm_logits = lm_logits + self.final_logits_bias.to(lm_logits.device)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\models\bart\modeling_bart.py:1528, in BartModel.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1521     encoder_outputs = BaseModelOutput(
#    1522         last_hidden_state=encoder_outputs[0],
#    1523         hidden_states=encoder_outputs[1] if len(encoder_outputs) > 1 else None,
#    1524         attentions=encoder_outputs[2] if len(encoder_outputs) > 2 else None,
#    1525     )
#    1527 # decoder outputs consists of (dec_features, past_key_value, dec_hidden, dec_attn)
# -> 1528 decoder_outputs = self.decoder(
#    1529     input_ids=decoder_input_ids,
#    1530     attention_mask=decoder_attention_mask,
#    1531     encoder_hidden_states=encoder_outputs[0],
#    1532     encoder_attention_mask=attention_mask,
#    1533     head_mask=decoder_head_mask,
#    1534     cross_attn_head_mask=cross_attn_head_mask,
#    1535     past_key_values=past_key_values,
#    1536     inputs_embeds=decoder_inputs_embeds,
#    1537     use_cache=use_cache,
#    1538     output_attentions=output_attentions,
#    1539     output_hidden_states=output_hidden_states,
#    1540     return_dict=return_dict,
#    1541 )
#    1543 if not return_dict:
#    1544     return decoder_outputs + encoder_outputs
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\models\bart\modeling_bart.py:1380, in BartDecoder.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, head_mask, cross_attn_head_mask, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1367     layer_outputs = self._gradient_checkpointing_func(
#    1368         decoder_layer.__call__,
#    1369         hidden_states,
#    (...)
#    1377         use_cache,
#    1378     )
#    1379 else:
# -> 1380     layer_outputs = decoder_layer(
#    1381         hidden_states,
#    1382         attention_mask=attention_mask,
#    1383         encoder_hidden_states=encoder_hidden_states,
#    1384         encoder_attention_mask=encoder_attention_mask,
#    1385         layer_head_mask=(head_mask[idx] if head_mask is not None else None),
#    1386         cross_attn_layer_head_mask=(
#    1387             cross_attn_head_mask[idx] if cross_attn_head_mask is not None else None
#    1388         ),
#    1389         past_key_value=past_key_value,
#    1390         output_attentions=output_attentions,
#    1391         use_cache=use_cache,
#    1392     )
#    1393 hidden_states = layer_outputs[0]
#    1395 if use_cache:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\models\bart\modeling_bart.py:666, in BartDecoderLayer.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, layer_head_mask, cross_attn_layer_head_mask, past_key_value, output_attentions, use_cache)
#     664 self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
#     665 # add present self-attn cache to positions 1,2 of present_key_value tuple
# --> 666 hidden_states, self_attn_weights, present_key_value = self.self_attn(
#     667     hidden_states=hidden_states,
#     668     past_key_value=self_attn_past_key_value,
#     669     attention_mask=attention_mask,
#     670     layer_head_mask=layer_head_mask,
#     671     output_attentions=output_attentions,
#     672 )
#     673 hidden_states = nn.functional.dropout(hidden_states, p=self.dropout, training=self.training)
#     674 hidden_states = residual + hidden_states
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\models\bart\modeling_bart.py:518, in BartSdpaAttention.forward(self, hidden_states, key_value_states, past_key_value, attention_mask, layer_head_mask, output_attentions)
#     514 # Use the `embed_dim` from the config (stored in the class) rather than `hidden_state` because `attn_output` can be
#     515 # partitioned across GPUs when using tensor-parallelism.
#     516 attn_output = attn_output.reshape(bsz, tgt_len, self.embed_dim)
# --> 518 attn_output = self.out_proj(attn_output)
#     520 return attn_output, None, past_key_value
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import networkx as nx
import matplotlib.pyplot as plt
import requests

# Charger le modèle REBEL
model_name = "Babelscape/rebel-large"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)


# Fonction pour découper le texte en blocs
def split_text(text, max_length=512):
    sentences = text.split(". ")
    blocks = []
    current_block = ""
    for sentence in sentences:
        if len(current_block) + len(sentence) <= max_length:
            current_block += sentence + ". "
        else:
            blocks.append(current_block.strip())
            current_block = sentence + ". "
    if current_block:
        blocks.append(current_block.strip())
    return blocks

# Extraction des entités et relations avec REBEL
def extract_entities_and_relations(block):
    inputs = tokenizer(block, return_tensors="pt", truncation=True, max_length=512)
    outputs = model.generate(**inputs)
    decoded_output = tokenizer.batch_decode(outputs, skip_special_tokens=True)
    print(f"Raw extraction output: {decoded_output[0]}")
    return decoded_output[0]

# Parser les triples extraits par REBEL
def parse_rebel_output(output):
    triples = []
    statements = output.split('\n')
    for statement in statements:
        parts = statement.split('  ')
        if len(parts) >= 3:
            subject = parts[0].strip()
            obj = parts[1].strip()
            relation = parts[2].strip()
            if subject and obj and relation:
                triples.append((subject, relation, obj))
    return triples

# Filtrer les triples pertinents
def filter_triples(triples, title, relevant_relations=None):
    if relevant_relations is None:
        relevant_relations = ["followed by", "follows"]
    filtered = []
    for triple in triples:
        subject, relation, obj = triple
        if title.lower() in subject.lower() or title.lower() in obj.lower() or relation.lower() in relevant_relations:
            filtered.append(triple)
    return filtered

# Créer un graphe NetworkX à partir des triples
def create_graph(triples):
    graph = nx.DiGraph()
    for triple in triples:
        print(f"Triple: {triple}")
        if len(triple) == 3 and all(triple):
            subject, relation, obj = triple
            graph.add_node(subject)
            graph.add_node(obj)
            graph.add_edge(subject, obj, label=relation)
    return graph

# Visualiser le graphe
def plot_graph(graph):
    plt.figure(figsize=(12, 8))
    if len(graph) == 0:
        print("Warning: Graph is empty!")
        return
    pos = nx.kamada_kawai_layout(graph)
    nx.draw_networkx_nodes(graph, pos, node_color="lightblue", node_size=3000)
    nx.draw_networkx_labels(graph, pos, font_size=10, font_weight="bold")
    nx.draw_networkx_edges(graph, pos)
    edge_labels = nx.get_edge_attributes(graph, 'label')
    nx.draw_networkx_edge_labels(graph, pos, edge_labels=edge_labels)
    plt.title("Knowledge Graph")
    plt.axis('off')
    plt.tight_layout()
    plt.show()

# Pipeline principal
title = "Ralph Breaks the Internet"
text = get_wikipedia_summary(title, language="en")

if text:
    text_blocks = split_text(text)
    triples = []

    for block in text_blocks:
        result = extract_entities_and_relations(block)
        block_triples = parse_rebel_output(result)
        triples.extend(block_triples)

    # Filtrer les triples pour garder uniquement ceux pertinents
    filtered_triples = filter_triples(triples, title, relevant_relations=["followed by", "follows"])

    print("\nFiltered Triples:")
    for triple in filtered_triples:
        print(triple)

    # Créer et afficher le graphe
    knowledge_graph = create_graph(filtered_triples)
    plot_graph(knowledge_graph)
# Out:
# Raw extraction output:  Ralph Breaks the Internet  Rich Moore  director  Phil Johnston  director  Clark Spencer  producer  Pamela Ribon  screenwriter  Walt Disney Animation Studios  Walt Disney Pictures  owned by  Walt Disney Pictures  Walt Disney Animation Studios  owner of  Wreck-It Ralph  Rich Moore  director  Phil Johnston  screenwriter  Clark Spencer  screenwriter  Pamela Ribon  screenwriter
# Raw extraction output:  first film  John C. Reilly  cast member  Sarah Silverman  cast member  Jack McBrayer  cast member  Jane Lynch  cast member  Ed O'Neill  cast member  Gal Gadot  cast member  Taraji P. Henson  cast member  Alfred Molina  cast member  Alan Tudyk  cast member
# Raw extraction output:  Vanellope von Schweetz  Wreck-It Ralph  present in work  Wreck-It Ralph  Vanellope von Schweetz  characters
# Raw extraction output:  Ralph Breaks the Internet  Walt Disney Animation Studios  production company  November 5, 2018  publication date  Ralph Breaks the Internet  Walt Disney Animation Studios  production company  November 5, 2018  publication date
# Raw extraction output:  Spider-Man: Into the Spider-Verse  Best Animated Feature  nominated for
# Raw extraction output:  Vanellope  Sugar Rush  present in work  Sugar Rush  Vanellope  characters  Vanellope  characters  Vanellope  Sugar Rush  present in work
# Raw extraction output:  Sugar Rush  Litwak  publisher  Sugar Rush  Litwak  publisher  Sugar Rush  Litwak  publisher
# Raw extraction output:  eBay  website  instance of  website  Internet  part of
# Raw extraction output:  Slaughter Race  battle royale game  genre
# Raw extraction output:  BuzzzTube  algorithm  instance of
# Raw extraction output:  I Want  Vanellope  performer
# Raw extraction output:  Slaughter Race  Sugar Rush  different from  Sugar Rush  Slaughter Race  different from
# Raw extraction output:  Slaughter Race  Ralph  characters  Vanellope  characters  Shank  characters  Ralph  characters
# Raw extraction output:  Vanellope  Ralph  present in work  Ralph  present in work  Ralph  present in work
# Raw extraction output:  Ralph  Vanellope  spouse  Vanellope  spouse  Vanellope  Ralph  spouse  Ralph  spouse  Ralph  Vanellope  spouse  Vanellope  spouse  Vanellope  Ralph  spouse  Ralph  spouse
# Raw extraction output:  Slaughter Race  Ralph  characters  Vanellope  characters  Ralph  characters
# Raw extraction output:  Wreck-It Ralph  Fix-It Felix Jr.  present in work  Fix-It Felix Jr.  Wreck-It Ralph  characters
# Raw extraction output:  Fix-It Felix Jr.  Jack McBrayer  performer
# Raw extraction output:  first film  Alfred Molina  cast member
# Raw extraction output:  Anna  Frozen  present in work  Elsa  Frozen  present in work  Frozen  Anna  characters  Elsa  characters
# Raw extraction output:  Sonic the Hedgehog  Roger Craig Smith  performer  Eeyore  Winnie the Pooh  present in work  Winnie the Pooh  Eeyore  characters  Grumpy  Snow White and the Seven Dwarfs  present in work  Groot  Vin Diesel  performer  Buzz Lightyear  Tim Allen  performer  Toy Story  present in work  Toy Story  Buzz Lightyear  characters
# Raw extraction output:  DanTDM  Sean Giambrone  performer
# Raw extraction output:  Slaughter Race  Rich Moore  director  Phil Johnston  director
# Raw extraction output:  Disney  Walt Disney Animation Studios  owner of  Pixar Animation Studios  owner of  Walt Disney Animation Studios  Disney  owned by  Pixar Animation Studios  Disney  owned by
# Raw extraction output:  Zero  Imagine Dragons  performer
# Raw extraction output:  C-3PO  R2-D2  said to be the same as  BB-8  said to be the same as  R2-D2  C-3PO  said to be the same as  BB-8  C-3PO  said to be the same as
# Raw extraction output:  King Kong  various films  present in work  various films  King Kong  characters
# Raw extraction output:  Godzilla  Wreck-It Ralph  derivative work  Wreck-It Ralph  Godzilla  based on
# Raw extraction output:  Tron  Henry Jackman  composer
# Raw extraction output:  Ralph Breaks the Internet  Walt Disney Animation Studios  production company  March 9, 2018  publication date  Phil Johnston  screenwriter  Clark Spencer  producer  Wreck-It Ralph 2  Walt Disney Animation Studios  production company  March 9, 2018  publication date  Phil Johnston  screenwriter  Clark Spencer  producer
# Raw extraction output:  Wreck-It Ralph 2  Josie Trinidad  screenwriter
# Raw extraction output:  Knowsmore  search engine  instance of
# Raw extraction output:  Ralph  Vanellope  spouse  Vanellope  Ralph  spouse
# Raw extraction output:  One Wilshire  Los Angeles  located in the administrative territorial entity
# Raw extraction output:  Internet memes  Internet  part of
# Raw extraction output:  Zootopia  racism  main subject
# Raw extraction output:  Judy Hopps  Zootopia  present in work  Zootopia  Judy Hopps  characters
# Raw extraction output:  Vanellope  Wreck-It Ralph  present in work  Vanellope  Wreck-It Ralph  present in work
# Raw extraction output:  Ralph  Vanellope  spouse  Vanellope  Ralph  spouse
# Raw extraction output:  KnowsMore  Alan Tudyk  performer
# Raw extraction output:  FN-3128  Michael Giacchino  performer
# Raw extraction output:  Cinderella  Jennifer Hale  performer  Aurora  Kate Higgins  performer
# Raw extraction output:  Disney Princesses  Ariel  has part  Belle  has part  Jasmine  has part  Mulan  has part  Tiana  has part  Ariel  Disney Princesses  part of  Belle  Disney Princesses  part of  Jasmine  Disney Princesses  part of  Mulan  Disney Princesses  part of  Tiana  Disney Princesses  part of
# Raw extraction output:  Tiana  The Princess and the Frog  present in work  The Princess and the Frog  Tiana  characters
# Raw extraction output:  Tiana  Anika Noni Rose  performer  Tiana  Anika Noni Rose  performer
# Raw extraction output:  Pocahontas  1995 film  present in work  1995 film  Pocahontas  characters
# Raw extraction output:  Never Gonna Give You Up  Rick Astley  performer
# Raw extraction output:  Zero  Imagine Dragons  performer
# Raw extraction output:  A Place Called Slaughter Race  Sarah Silverman  performer  Gal Gadot  performer  Tom MacDougall  composer  Phil Johnston  director  Alan Menken  composer  In This Place  Julia Michaels  performer
# Raw extraction output:  Let it Go  Demi Lovato  performer  Never Gonna Give You Up  Rick Astley  performer
# Raw extraction output:  Fortnite Battle Royale  November 16, 2018  publication date
# Raw extraction output:  Google Home  Google  developer  Google BrandLab  Google  owned by  Google  Google BrandLab  owner of
# Raw extraction output:  FireTV  Amazon  developer  Kindle Fire  Amazon  developer
# Raw extraction output:  Ralph Breaks VR  virtual reality  instance of
# Raw extraction output:  Disney Magic Kingdoms  world builder  genre
# Raw extraction output:  Ralph Breaks the Internet  November 5, 2018  publication date
# Raw extraction output:  Ralph Breaks the Internet  Walt Disney Studios Home Entertainment  distributed by
# Raw extraction output:  DVD  Blu-ray  followed by
# Raw extraction output:  Ralph Breaks the Internet  United States  country of origin  Ralph Breaks the Internet  United States  country of origin
# Raw extraction output:  Frozen  Disney  production company
# Raw extraction output:  Rotten Tomatoes  review aggregator  instance of
# Raw extraction output:  Ralph Breaks the Internet  predecessor  follows  predecessor  Ralph Breaks the Internet  followed by
# Raw extraction output:  Bilge Ebiri  The New York Times  employer
# Raw extraction output:  Brian Lowry  CNN  employer
# Raw extraction output:  Peter Hartlaub  San Francisco Chronicle  employer
# Raw extraction output:  Ready Player One  science fiction film  genre
# Raw extraction output:  Oliver Jones  The New York Observer  employer
# Raw extraction output:  Peter Bradshaw  The Guardian  employer
# Raw extraction output:  Ralph Breaks the Internet  Disney A to Z  distributed by  Ralph Breaks the Internet  Disney A to Z  distributed by
#
# Filtered Triples:
# ('Ralph Breaks the Internet', 'director', 'Rich Moore')
# ('Ralph Breaks the Internet', 'production company', 'Walt Disney Animation Studios')
# ('Ralph Breaks the Internet', 'production company', 'Walt Disney Animation Studios')
# ('Ralph Breaks the Internet', 'publication date', 'November 5, 2018')
# ('Ralph Breaks the Internet', 'distributed by', 'Walt Disney Studios Home Entertainment')
# ('DVD', 'followed by', 'Blu-ray')
# ('Ralph Breaks the Internet', 'country of origin', 'United States')
# ('Ralph Breaks the Internet', 'follows', 'predecessor')
# ('Ralph Breaks the Internet', 'distributed by', 'Disney A to Z')
# Triple: ('Ralph Breaks the Internet', 'director', 'Rich Moore')
# Triple: ('Ralph Breaks the Internet', 'production company', 'Walt Disney Animation Studios')
# Triple: ('Ralph Breaks the Internet', 'production company', 'Walt Disney Animation Studios')
# Triple: ('Ralph Breaks the Internet', 'publication date', 'November 5, 2018')
# Triple: ('Ralph Breaks the Internet', 'distributed by', 'Walt Disney Studios Home Entertainment')
# Triple: ('DVD', 'followed by', 'Blu-ray')
# Triple: ('Ralph Breaks the Internet', 'country of origin', 'United States')
# Triple: ('Ralph Breaks the Internet', 'follows', 'predecessor')
# Triple: ('Ralph Breaks the Internet', 'distributed by', 'Disney A to Z')

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import networkx as nx
import matplotlib.pyplot as plt
import requests

# Charger le modèle REBEL
model_name = "Babelscape/rebel-large"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)


def get_wikipedia_summary(title, year=-1, language="en"):
    """
    Récupère le résumé d'un article Wikipédia ou sélectionne une sous-page pertinente.
    :param title: Titre de la page Wikipédia.
    :param year: Année associée au film (par défaut -1 pour ignorer).
    :param language: Langue de l'article (par défaut "en").
    :return: Résumé textuel de l'article.
    """
    url = f"https://{language}.wikipedia.org/w/api.php"
    params = {
        "action": "query",
        "format": "json",
        "titles": title,
        "prop": "extracts",
        "explaintext": True,
        "redirects": 1  # Suivre les redirections
    }

    response = requests.get(url, params=params)
    if response.status_code == 200:
        data = response.json()
        page = next(iter(data["query"]["pages"].values()))

        # Cas où la page contient "may refer to"
        if "extract" in page and "may refer to" in page["extract"]:
            # Extraire les sous-pages mentionnées dans la section
            subpages = re.findall(r"(?<=\n)Frozen \((.*?)\)", page["extract"])
            if year != -1:
                # Filtrer les sous-pages contenant l'année
                matching_pages = [sp for sp in subpages if str(year) in sp]
                if matching_pages:
                    print(f"Correspondance trouvée : Frozen ({matching_pages[0]})")
                    return get_wikipedia_summary(f"Frozen ({matching_pages[0]})", language=language)
            # Si aucune correspondance avec l'année, choisir la première sous-page
            if subpages:
                print(f"Aucune année précise trouvée. Sélection de : Frozen ({subpages[0]})")
                return get_wikipedia_summary(f"Frozen ({subpages[0]})", language=language)
            else:
                print("Aucune sous-page identifiable.")
                return None

        # Retourner le résumé de la page normale
        if "extract" in page:
            return page["extract"]
        else:
            print(f"Aucun résumé trouvé pour le titre '{title}'.")
            return None
    else:
        print(f"Erreur lors de la requête : {response.status_code}")
        return None



# Fonction pour découper le texte en blocs
def split_text(text, max_length=512):
    sentences = text.split(". ")
    blocks = []
    current_block = ""
    for sentence in sentences:
        if len(current_block) + len(sentence) <= max_length:
            current_block += sentence + ". "
        else:
            blocks.append(current_block.strip())
            current_block = sentence + ". "
    if current_block:
        blocks.append(current_block.strip())
    return blocks


# Extraction des entités et relations avec REBEL
def extract_entities_and_relations(block):
    inputs = tokenizer(block, return_tensors="pt", truncation=True, max_length=512)
    outputs = model.generate(**inputs)
    decoded_output = tokenizer.batch_decode(outputs, skip_special_tokens=True)
    print(f"Raw extraction output: {decoded_output[0]}")
    return decoded_output[0]


# Parser les triples extraits par REBEL
def parse_rebel_output(output):
    triples = []
    statements = output.split('\n')
    for statement in statements:
        parts = statement.split('  ')
        if len(parts) >= 3:
            subject = parts[0].strip()
            obj = parts[1].strip()
            relation = parts[2].strip()
            if subject and obj and relation:
                triples.append((subject, relation, obj))
    return triples


# Filtrer les triples pertinents
def filter_triples(triples, title, relevant_relations=None):
    if relevant_relations is None:
        relevant_relations = ["followed by", "follows"]
    filtered = []
    for triple in triples:
        subject, relation, obj = triple
        if title.lower() in subject.lower() or title.lower() in obj.lower() or relation.lower() in relevant_relations:
            filtered.append(triple)
    return filtered


# Créer un graphe NetworkX à partir des triples
def create_graph(triples):
    graph = nx.DiGraph()
    for triple in triples:
        print(f"Triple: {triple}")
        if len(triple) == 3 and all(triple):
            subject, relation, obj = triple
            graph.add_node(subject)
            graph.add_node(obj)
            graph.add_edge(subject, obj, label=relation)
    return graph


# Visualiser le graphe
def plot_graph(graph, title):
    plt.figure(figsize=(12, 8))
    if len(graph) == 0:
        print(f"Warning: Graph for '{title}' is empty!")
        return
    pos = nx.kamada_kawai_layout(graph)
    nx.draw_networkx_nodes(graph, pos, node_color="lightblue", node_size=3000)
    nx.draw_networkx_labels(graph, pos, font_size=10, font_weight="bold")
    nx.draw_networkx_edges(graph, pos)
    edge_labels = nx.get_edge_attributes(graph, 'label')
    nx.draw_networkx_edge_labels(graph, pos, edge_labels=edge_labels)
    plt.title(f"Knowledge Graph for '{title}'")
    plt.axis('off')
    plt.tight_layout()
    plt.show()


# Pipeline principal pour une liste de films
film_titles = [
    "Ralph Breaks the Internet",
    "Frozen",
    "Inception",
    "The Matrix"
]

for title in film_titles:
    print(f"\nTraitement du film : {title}")
    text = get_wikipedia_summary(title, language="en")
    
    if text:
        text_blocks = split_text(text)
        triples = []

        for block in text_blocks:
            result = extract_entities_and_relations(block)
            block_triples = parse_rebel_output(result)
            triples.extend(block_triples)

        # Filtrer les triples pour garder uniquement ceux pertinents
        filtered_triples = filter_triples(triples, title, relevant_relations=["followed by", "follows"])

        print(f"\nFiltered Triples for '{title}':")
        for triple in filtered_triples:
            print(triple)

        # Créer et afficher le graphe
        knowledge_graph = create_graph(filtered_triples)
        plot_graph(knowledge_graph, title)
    else:
        print(f"Pas de données trouvées pour '{title}'.")
# Out:
# Traitement du film : Ralph Breaks the Internet
# Raw extraction output:  Ralph Breaks the Internet  Rich Moore  director  Phil Johnston  director  Clark Spencer  producer  Pamela Ribon  screenwriter  Walt Disney Animation Studios  Walt Disney Pictures  owned by  Walt Disney Pictures  Walt Disney Animation Studios  owner of  Wreck-It Ralph  Rich Moore  director  Phil Johnston  screenwriter  Clark Spencer  screenwriter  Pamela Ribon  screenwriter
# Raw extraction output:  first film  John C. Reilly  cast member  Sarah Silverman  cast member  Jack McBrayer  cast member  Jane Lynch  cast member  Ed O'Neill  cast member  Gal Gadot  cast member  Taraji P. Henson  cast member  Alfred Molina  cast member  Alan Tudyk  cast member
# Raw extraction output:  Vanellope von Schweetz  Wreck-It Ralph  present in work  Wreck-It Ralph  Vanellope von Schweetz  characters
# Raw extraction output:  Ralph Breaks the Internet  Walt Disney Animation Studios  production company  November 5, 2018  publication date  Ralph Breaks the Internet  Walt Disney Animation Studios  production company  November 5, 2018  publication date
# Raw extraction output:  Spider-Man: Into the Spider-Verse  Best Animated Feature  nominated for
# Raw extraction output:  Vanellope  Sugar Rush  present in work  Sugar Rush  Vanellope  characters  Vanellope  characters  Vanellope  Sugar Rush  present in work
# Raw extraction output:  Sugar Rush  Litwak  publisher  Sugar Rush  Litwak  publisher  Sugar Rush  Litwak  publisher
# Raw extraction output:  eBay  website  instance of  website  Internet  part of
# Raw extraction output:  Slaughter Race  battle royale game  genre
# Raw extraction output:  BuzzzTube  algorithm  instance of
# Raw extraction output:  I Want  Vanellope  performer
# Raw extraction output:  Slaughter Race  Sugar Rush  different from  Sugar Rush  Slaughter Race  different from
# Raw extraction output:  Slaughter Race  Ralph  characters  Vanellope  characters  Shank  characters  Ralph  characters
# Raw extraction output:  Vanellope  Ralph  present in work  Ralph  present in work  Ralph  present in work
# Raw extraction output:  Ralph  Vanellope  spouse  Vanellope  spouse  Vanellope  Ralph  spouse  Ralph  spouse  Ralph  Vanellope  spouse  Vanellope  spouse  Vanellope  Ralph  spouse  Ralph  spouse
# Raw extraction output:  Slaughter Race  Ralph  characters  Vanellope  characters  Ralph  characters
# Raw extraction output:  Wreck-It Ralph  Fix-It Felix Jr.  present in work  Fix-It Felix Jr.  Wreck-It Ralph  characters
# Raw extraction output:  Fix-It Felix Jr.  Jack McBrayer  performer
# Raw extraction output:  first film  Alfred Molina  cast member
# Raw extraction output:  Anna  Frozen  present in work  Elsa  Frozen  present in work  Frozen  Anna  characters  Elsa  characters
# Raw extraction output:  Sonic the Hedgehog  Roger Craig Smith  performer  Eeyore  Winnie the Pooh  present in work  Winnie the Pooh  Eeyore  characters  Grumpy  Snow White and the Seven Dwarfs  present in work  Groot  Vin Diesel  performer  Buzz Lightyear  Tim Allen  performer  Toy Story  present in work  Toy Story  Buzz Lightyear  characters
# Raw extraction output:  DanTDM  Sean Giambrone  performer
# Raw extraction output:  Slaughter Race  Rich Moore  director  Phil Johnston  director
# Raw extraction output:  Disney  Walt Disney Animation Studios  owner of  Pixar Animation Studios  owner of  Walt Disney Animation Studios  Disney  owned by  Pixar Animation Studios  Disney  owned by
# Raw extraction output:  Zero  Imagine Dragons  performer
# Raw extraction output:  C-3PO  R2-D2  said to be the same as  BB-8  said to be the same as  R2-D2  C-3PO  said to be the same as  BB-8  C-3PO  said to be the same as
# Raw extraction output:  King Kong  various films  present in work  various films  King Kong  characters
# Raw extraction output:  Godzilla  Wreck-It Ralph  derivative work  Wreck-It Ralph  Godzilla  based on
# Raw extraction output:  Tron  Henry Jackman  composer
# Raw extraction output:  Ralph Breaks the Internet  Walt Disney Animation Studios  production company  March 9, 2018  publication date  Phil Johnston  screenwriter  Clark Spencer  producer  Wreck-It Ralph 2  Walt Disney Animation Studios  production company  March 9, 2018  publication date  Phil Johnston  screenwriter  Clark Spencer  producer
# Raw extraction output:  Wreck-It Ralph 2  Josie Trinidad  screenwriter
# Raw extraction output:  Knowsmore  search engine  instance of
# Raw extraction output:  Ralph  Vanellope  spouse  Vanellope  Ralph  spouse
# Raw extraction output:  One Wilshire  Los Angeles  located in the administrative territorial entity
# Raw extraction output:  Internet memes  Internet  part of
# Raw extraction output:  Zootopia  racism  main subject
# Raw extraction output:  Judy Hopps  Zootopia  present in work  Zootopia  Judy Hopps  characters
# Raw extraction output:  Vanellope  Wreck-It Ralph  present in work  Vanellope  Wreck-It Ralph  present in work
# Raw extraction output:  Ralph  Vanellope  spouse  Vanellope  Ralph  spouse
# Raw extraction output:  KnowsMore  Alan Tudyk  performer
# Raw extraction output:  FN-3128  Michael Giacchino  performer
# Raw extraction output:  Cinderella  Jennifer Hale  performer  Aurora  Kate Higgins  performer
# Raw extraction output:  Disney Princesses  Ariel  has part  Belle  has part  Jasmine  has part  Mulan  has part  Tiana  has part  Ariel  Disney Princesses  part of  Belle  Disney Princesses  part of  Jasmine  Disney Princesses  part of  Mulan  Disney Princesses  part of  Tiana  Disney Princesses  part of
# Raw extraction output:  Tiana  The Princess and the Frog  present in work  The Princess and the Frog  Tiana  characters
# Raw extraction output:  Tiana  Anika Noni Rose  performer  Tiana  Anika Noni Rose  performer
# Raw extraction output:  Pocahontas  1995 film  present in work  1995 film  Pocahontas  characters
# Raw extraction output:  Never Gonna Give You Up  Rick Astley  performer
# Raw extraction output:  Zero  Imagine Dragons  performer
# Raw extraction output:  A Place Called Slaughter Race  Sarah Silverman  performer  Gal Gadot  performer  Tom MacDougall  composer  Phil Johnston  director  Alan Menken  composer  In This Place  Julia Michaels  performer
# Raw extraction output:  Let it Go  Demi Lovato  performer  Never Gonna Give You Up  Rick Astley  performer
# Raw extraction output:  Fortnite Battle Royale  November 16, 2018  publication date
# Raw extraction output:  Google Home  Google  developer  Google BrandLab  Google  owned by  Google  Google BrandLab  owner of
# Raw extraction output:  FireTV  Amazon  developer  Kindle Fire  Amazon  developer
# Raw extraction output:  Ralph Breaks VR  virtual reality  instance of
# Raw extraction output:  Disney Magic Kingdoms  world builder  genre
# Raw extraction output:  Ralph Breaks the Internet  November 5, 2018  publication date
# Raw extraction output:  Ralph Breaks the Internet  Walt Disney Studios Home Entertainment  distributed by
# Raw extraction output:  DVD  Blu-ray  followed by
# Raw extraction output:  Ralph Breaks the Internet  United States  country of origin  Ralph Breaks the Internet  United States  country of origin
# Raw extraction output:  Frozen  Disney  production company
# Raw extraction output:  Rotten Tomatoes  review aggregator  instance of
# Raw extraction output:  Ralph Breaks the Internet  predecessor  follows  predecessor  Ralph Breaks the Internet  followed by
# Raw extraction output:  Bilge Ebiri  The New York Times  employer
# Raw extraction output:  Brian Lowry  CNN  employer
# Raw extraction output:  Peter Hartlaub  San Francisco Chronicle  employer
# Raw extraction output:  Ready Player One  science fiction film  genre
# Raw extraction output:  Oliver Jones  The New York Observer  employer
# Raw extraction output:  Peter Bradshaw  The Guardian  employer
# Raw extraction output:  Ralph Breaks the Internet  Disney A to Z  distributed by  Ralph Breaks the Internet  Disney A to Z  distributed by
#
# Filtered Triples for 'Ralph Breaks the Internet':
# ('Ralph Breaks the Internet', 'director', 'Rich Moore')
# ('Ralph Breaks the Internet', 'production company', 'Walt Disney Animation Studios')
# ('Ralph Breaks the Internet', 'production company', 'Walt Disney Animation Studios')
# ('Ralph Breaks the Internet', 'publication date', 'November 5, 2018')
# ('Ralph Breaks the Internet', 'distributed by', 'Walt Disney Studios Home Entertainment')
# ('DVD', 'followed by', 'Blu-ray')
# ('Ralph Breaks the Internet', 'country of origin', 'United States')
# ('Ralph Breaks the Internet', 'follows', 'predecessor')
# ('Ralph Breaks the Internet', 'distributed by', 'Disney A to Z')
# Triple: ('Ralph Breaks the Internet', 'director', 'Rich Moore')
# Triple: ('Ralph Breaks the Internet', 'production company', 'Walt Disney Animation Studios')
# Triple: ('Ralph Breaks the Internet', 'production company', 'Walt Disney Animation Studios')
# Triple: ('Ralph Breaks the Internet', 'publication date', 'November 5, 2018')
# Triple: ('Ralph Breaks the Internet', 'distributed by', 'Walt Disney Studios Home Entertainment')
# Triple: ('DVD', 'followed by', 'Blu-ray')
# Triple: ('Ralph Breaks the Internet', 'country of origin', 'United States')
# Triple: ('Ralph Breaks the Internet', 'follows', 'predecessor')
# Triple: ('Ralph Breaks the Internet', 'distributed by', 'Disney A to Z')
# Traitement du film : Frozen
# Raw extraction output:  World War I  World War II  followed by  World War II  World War I  follows
# Raw extraction output:  Sentenced  1998  work period (start)  The Heart of Everything  2007  publication date  Hans Christian Andersen  The Snow Queen  notable work  The Snow Queen  Hans Christian Andersen  author
#
# Filtered Triples for 'Frozen':
# ('World War I', 'followed by', 'World War II')
# Triple: ('World War I', 'followed by', 'World War II')
# Traitement du film : Inception
# Raw extraction output:  Inception  action  genre  heist  genre  Christopher Nolan  director  Leonardo DiCaprio  cast member  Emma Thomas  producer  Christopher Nolan  Emma Thomas  spouse  Emma Thomas  Christopher Nolan  spouse
# Raw extraction output:  Insomnia  Ken Watanabe  cast member  Joseph Gordon-Levitt  cast member  Marion Cotillard  cast member  Elliot Page  cast member  Tom Hardy  cast member  Cillian Murphy  cast member  Tom Berenger  cast member  Dileep Rao  cast member  Michael Caine  cast member
# Raw extraction output:  Batman Begins  Warner Bros.  distributed by  The Prestige  Warner Bros.  distributed by  The Dark Knight  Warner Bros.  distributed by
# Raw extraction output:  Inception  July 8, 2010  publication date  July 16, 2010  publication date  Inception  July 8, 2010  publication date  July 16, 2010  publication date
# Raw extraction output:  Inception  Best Cinematography  award received  Best Sound Editing  award received  Best Sound Mixing  award received  Best Visual Effects  nominated for  Best Picture  nominated for  Best Original Screenplay  nominated for  Best Art Direction  nominated for  Best Original Score  nominated for  Best Cinematography  Oscars  instance of  Best Sound Editing  Oscars  instance of  Best Sound Mixing  Oscars  instance of  Best Visual Effects  Oscars  instance of
# Raw extraction output:  Robert Fischer  Maurice Fischer  father  Maurice Fischer  Robert Fischer  child
# Raw extraction output:  Cobb  Mal  spouse  Cobb  Mal  spouse  Cobb  Mal  spouse  Mal  Cobb  spouse  Cobb  spouse  Cobb  spouse
# Raw extraction output:  Non, je ne regrette rien  French  country of origin
# Raw extraction output:  Peter Browning  godfather  position held
# Raw extraction output:  Arthur  Yusuf  present in work
# Raw extraction output:  Browning  Robert  student  Robert  student  Robert  student  Robert  Browning  student  Robert  Browning  student
# Raw extraction output:  Arthur  Eames  sibling  Cobb  sibling  Ariadne  sibling  Eames  Arthur  sibling  Cobb  sibling  Ariadne  sibling  Cobb  Arthur  sibling  Eames  sibling  Ariadne  sibling  Ariadne  Arthur  sibling  Eames  sibling  Cobb  sibling
# Raw extraction output:  Limbo  Cobb  characters  Cobb  characters  Cobb  characters  Cobb  Limbo  present in work  Cobb  Limbo  present in work  Cobb  Limbo  present in work
# Raw extraction output:  Saito  Limbo  present in work  Limbo  Saito  characters  Saito  characters  Saito  Limbo  present in work
# Raw extraction output:  Dom Cobb  Leonardo DiCaprio  performer
# Raw extraction output:  Batman Begins  Ken Watanabe  cast member
# Raw extraction output:  Arthur  Joseph Gordon-Levitt  performer
# Raw extraction output:  Arthur  Marion Cotillard  performer  Arthur  Marion Cotillard  performer
# Raw extraction output:  Cobb  extractor  uses  extractor  Cobb  used by
# Raw extraction output:  Ariadne  Elliot Page  cast member
# Raw extraction output:  Ariadne  Minos  father  Minos  Ariadne  child
# Raw extraction output:  identity theft  forgery  subclass of
# Raw extraction output:  Eames  dream world  present in work  dream world  Eames  characters
# Raw extraction output:  Robert Fischer  Cillian Murphy  performer
# Raw extraction output:  Rupert Murdoch  sons  child  sons  Rupert Murdoch  father
# Raw extraction output:  Yusuf  Dileep Rao  performer
# Raw extraction output:  Cobb  pharmacologist  field of work
# Raw extraction output:  Blonde  Talulah Riley  performer
# Raw extraction output:  Robert Fischer  Pete Postlethwaite  performer
# Raw extraction output:  Inception  heist film  genre
# Raw extraction output:  Batman Begins  Warner Bros.  production company  The Dark Knight  Warner Bros.  production company
# Raw extraction output:  Inception  The Dark Knight  based on
# Raw extraction output:  Inception  Leonardo DiCaprio  cast member
# Raw extraction output:   93–94   DiCaprio  cast member  DiCaprio  cast member  DiCaprio  cast member  DiCaprio   93–94   notable work  DiCaprio   93–94   notable work
# Raw extraction output:  the movie  Warner Bros.  distributed by
# Raw extraction output:  Cardington  United Kingdom  country  Bedfordshire  United Kingdom  country
# Raw extraction output:  2001: A Space Odyssey  Stanley Kubrick  director
# Raw extraction output:  Arthur  Joseph Gordon-Levitt  performer
# Raw extraction output:  Unforgiven  Ben Stiller  cast member
# Raw extraction output:  Musée Galliera  Paris  located in the administrative territorial entity  Rue César Franck  Paris  located in the administrative territorial entity  Rue Bouchut  Paris  located in the administrative territorial entity  Bir-Hakeim bridge  Paris  located in the administrative territorial entity
# Raw extraction output:  Tangier  Morocco  country
# Raw extraction output:  Malibu Beach  Los Angeles  located in the administrative territorial entity
# Raw extraction output:  Nijō Castle  1603  inception
# Raw extraction output:  Schuyler Heim Bridge  L.A.  located in the administrative territorial entity
# Raw extraction output:  Dileep Rao  actor  occupation
# Raw extraction output:  CAA building  Century City  located in the administrative territorial entity
# Raw extraction output:  Fortress Mountain  Alberta  located in the administrative territorial entity
# Raw extraction output:  On Her Majesty's Secret Service  James Bond  part of the series
# Raw extraction output:  The Dark Knight  IMAX  uses
# Raw extraction output:  Super Dimension 70  large-format  instance of
# Raw extraction output:  Photo-Sonics  35 mm  product or material produced
# Raw extraction output:  3D  2D  opposite of  2D  3D  opposite of
# Raw extraction output:  Inception  Warner Bros.  distributed by
# Raw extraction output:  Wally Pfister  3D  field of work
# Raw extraction output:  practical effects  computer-generated imagery  opposite of
# Raw extraction output:  Paul Franklin  visual effects supervisor  occupation
# Raw extraction output:  gravity  physics  facet of
# Raw extraction output:  iceberg  glacier  part of  glacier  iceberg  has part
# Raw extraction output:  Paris-folding sequence  principal photography  part of  principal photography  Paris-folding sequence  has part
# Raw extraction output:  Inception  Hans Zimmer  composer  Inception  Hans Zimmer  composer
# Raw extraction output:  Non, je ne regrette rien  Édith Piaf  performer
# Raw extraction output:  Hans Zimmer  Best Original Score  nominated for  Best Original Score  Academy Award  instance of  Trent Reznor  Best Original Score  nominated for  Atticus Ross  Best Original Score  nominated for  The Social Network  Best Original Score  nominated for  Atticus Ross  composer
# Raw extraction output:  plot  characters  characters  characters  plot  present in work
# Raw extraction output:  Luis Buñuel  Belle de Jour  notable work  The Discreet Charm of the Bourgeoisie  notable work  Belle de Jour  Luis Buñuel  author  The Discreet Charm of the Bourgeoisie  Luis Buñuel  author
# Raw extraction output:  Deirdre Barrett  Harvard University  employer
# Raw extraction output:  waking him up  conscious dream  facet of
# Raw extraction output:  cinema  filmmaking  studied by
# Raw extraction output:  Jonah Lehrer  Wired  employer
# Raw extraction output:  Inception  narrative arc  genre
# Raw extraction output:  dream  subconscious  facet of
# Raw extraction output:  Bir-Hakeim bridge  Paris  located in the administrative territorial entity
# Raw extraction output:  femme fatale  key noir  said to be the same as  key noir  femme fatale  said to be the same as
# Raw extraction output:  caper  heist movie  subclass of
# Raw extraction output:  Inception  Kristin Thompson  screenwriter
# Raw extraction output:  Jorge Luis Borges  The Secret Miracle  notable work  The Circular Ruins  notable work  The Secret Miracle  Jorge Luis Borges  author  The Circular Ruins  Jorge Luis Borges  author
# Raw extraction output:  Paprika  2006  publication date
# Raw extraction output:  the film's script  Nolan  author  Nolan  author
# Raw extraction output:  Dream  reality  opposite of
# Raw extraction output:  2023  2023  point in time
# Raw extraction output:  Inception  Warner Bros.  distributed by
# Raw extraction output:  Michael Tritter  Senior VP of Interactive Marketing  occupation
# Raw extraction output:  viral marketing  website  subclass of
# Raw extraction output:  Mind Crime  online game  instance of
# Raw extraction output:  Inception  May 10, 2010  publication date  Inception  May 10, 2010  publication date
# Raw extraction output:  Mind Heist  Zack Hemsey  performer
# Raw extraction output:  Inception  2010  publication date
# Raw extraction output:  DVD  Blu-ray  followed by
# Raw extraction output:  Inception  December 19, 2017  publication date
# Raw extraction output:  Inception  Nolan  director
# Raw extraction output:  Inception  Warner Bros.  distributed by
# Raw extraction output:  Inception  July 16, 2010  publication date
# Raw extraction output:  Inception  July 8, 2010  publication date
# Raw extraction output:  Avatar  2009  publication date
# Raw extraction output:  Inception  United States  country of origin
# Raw extraction output:  sixth-highest-grossing film of 2010 in North America  2010  point in time  2010  point in time  fourth-highest-grossing film of 2010  2010  point in time  2010  point in time
# Raw extraction output:  Inception  Leonardo DiCaprio  cast member  Inception  Leonardo DiCaprio  cast member
# Raw extraction output:  Metacritic  review aggregator  instance of
# Raw extraction output:  Inception  William Gibson  after a work by  Inception  William Gibson  after a work by
# Raw extraction output:  Roger Ebert  Chicago Sun-Times  employer
# Raw extraction output:  Inception  2010  publication date  Inception  2010  publication date  Inception  2010  publication date
# Raw extraction output:  Claudia Puig  USA Today  employer
# Raw extraction output:  David Edelstein  New York magazine  employer
# Raw extraction output:  Inception  Christopher Nolan  director
# Raw extraction output:  David Denby  New Yorker  employer
# Raw extraction output:  Inception  film-making  main subject
# Raw extraction output:  Paprika  Satoshi Kon  director  Yasutaka Tsutsui  1993 novel of the same name  notable work  1993 novel of the same name  Yasutaka Tsutsui  author
# Raw extraction output:  The Dream of a Lifetime  2002  publication date  Don Rosa  author
# Raw extraction output:  The Social Network  2010  publication date  Toy Story 3  2010  publication date  True Grit  2010  publication date  The King's Speech  2010  publication date  Black Swan  2010  publication date
# Raw extraction output:  Richard Roeper  Chicago Sun-Times  employer  Kenneth Turan  Los Angeles Times  employer
# Raw extraction output:  Kirk Honeycutt  The Hollywood Reporter  employer
# Raw extraction output:  Hollywood's 100 Favorite Films  The Hollywood Reporter  published in
# Raw extraction output:  Inception  The Most Influential Visual Effects Films of All Time  award received  Inception  The Most Influential Visual Effects Films of All Time  award received  Inception  The Most Influential Visual Effects Films of All Time  award received
# Raw extraction output:  Forbes magazine  Top 150 Greatest Films of 21st Century  has part  Top 150 Greatest Films of 21st Century  Forbes magazine  publisher
# Raw extraction output:  Best Cinematography  Academy Awards  instance of  Best Sound Editing  Academy Awards  instance of  Best Sound Mixing  Academy Awards  instance of  Best Visual Effects  Academy Awards  instance of  Best Production Design  British Academy Film Awards  instance of  Best Special Visual Effects  British Academy Film Awards  instance of  Best Sound  British Academy Film Awards  instance of
# Raw extraction output:  The Social Network  Film, Director, and Screenplay  nominated for  The King's Speech  Film, Director, and Screenplay  nominated for
# Raw extraction output:  Just Can't Get Enough  Black Eyed Peas  performer  6 Foot 7 Foot  Lil Wayne  performer  On the Floor  Jennifer Lopez  performer
# Raw extraction output:  South Park  fourteenth season  has part  fourteenth season  South Park  part of the series  Sheeption  has part  Sheeption  South Park  part of the series  fourteenth season  season  No Tears Left to Cry  Ariana Grande  performer  Lawnmower Dog  Rick and Morty  part of the series
# Raw extraction output:  How I Wet Your Mother  The Simpsons  part of the series  The Flash  season 4  has part  season 4  The Flash  part of the series
# Raw extraction output:  The Three Stigmata  Palmer Eldritch  author  Palmer Eldritch  The Three Stigmata  notable work
#
# Filtered Triples for 'Inception':
# ('Inception', 'genre', 'action')
# ('Inception', 'publication date', 'July 8, 2010')
# ('Inception', 'award received', 'Best Cinematography')
# ('Inception', 'genre', 'heist film')
# ('Inception', 'based on', 'The Dark Knight')
# ('Inception', 'cast member', 'Leonardo DiCaprio')
# ('Inception', 'distributed by', 'Warner Bros.')
# ('Inception', 'composer', 'Hans Zimmer')
# ('Inception', 'genre', 'narrative arc')
# ('Inception', 'screenwriter', 'Kristin Thompson')
# ('Inception', 'distributed by', 'Warner Bros.')
# ('Inception', 'publication date', 'May 10, 2010')
# ('Inception', 'publication date', '2010')
# ('DVD', 'followed by', 'Blu-ray')
# ('Inception', 'publication date', 'December 19, 2017')
# ('Inception', 'director', 'Nolan')
# ('Inception', 'distributed by', 'Warner Bros.')
# ('Inception', 'publication date', 'July 16, 2010')
# ('Inception', 'publication date', 'July 8, 2010')
# ('Inception', 'country of origin', 'United States')
# ('Inception', 'cast member', 'Leonardo DiCaprio')
# ('Inception', 'after a work by', 'William Gibson')
# ('Inception', 'publication date', '2010')
# ('Inception', 'director', 'Christopher Nolan')
# ('Inception', 'main subject', 'film-making')
# ('Inception', 'award received', 'The Most Influential Visual Effects Films of All Time')
# Triple: ('Inception', 'genre', 'action')
# Triple: ('Inception', 'publication date', 'July 8, 2010')
# Triple: ('Inception', 'award received', 'Best Cinematography')
# Triple: ('Inception', 'genre', 'heist film')
# Triple: ('Inception', 'based on', 'The Dark Knight')
# Triple: ('Inception', 'cast member', 'Leonardo DiCaprio')
# Triple: ('Inception', 'distributed by', 'Warner Bros.')
# Triple: ('Inception', 'composer', 'Hans Zimmer')
# Triple: ('Inception', 'genre', 'narrative arc')
# Triple: ('Inception', 'screenwriter', 'Kristin Thompson')
# Triple: ('Inception', 'distributed by', 'Warner Bros.')
# Triple: ('Inception', 'publication date', 'May 10, 2010')
# Triple: ('Inception', 'publication date', '2010')
# Triple: ('DVD', 'followed by', 'Blu-ray')
# Triple: ('Inception', 'publication date', 'December 19, 2017')
# Triple: ('Inception', 'director', 'Nolan')
# Triple: ('Inception', 'distributed by', 'Warner Bros.')
# Triple: ('Inception', 'publication date', 'July 16, 2010')
# Triple: ('Inception', 'publication date', 'July 8, 2010')
# Triple: ('Inception', 'country of origin', 'United States')
# Triple: ('Inception', 'cast member', 'Leonardo DiCaprio')
# Triple: ('Inception', 'after a work by', 'William Gibson')
# Triple: ('Inception', 'publication date', '2010')
# Triple: ('Inception', 'director', 'Christopher Nolan')
# Triple: ('Inception', 'main subject', 'film-making')
# Triple: ('Inception', 'award received', 'The Most Influential Visual Effects Films of All Time')
# Traitement du film : The Matrix
# Raw extraction output:  The Matrix  Matrix film series  part of the series  Keanu Reeves  cast member  Laurence Fishburne  cast member  Carrie-Anne Moss  cast member  Hugo Weaving  cast member  Joe Pantoliano  cast member  Matrix film series  The Matrix  has part  Keanu Reeves  cast member  Laurence Fishburne  cast member  Carrie-Anne Moss  cast member  Hugo Weaving  cast member  Joe Pantoliano  cast member
# Raw extraction output:  Bound  Warner Bros.  distributed by
# Raw extraction output:  The Matrix  March 31, 1999  publication date
# Raw extraction output:  Best Visual Effects  Academy Awards  instance of  Best Film Editing  Academy Awards  instance of  Best Sound  Academy Awards  instance of  Best Sound Editing  Academy Awards  instance of
# Raw extraction output:  Best Sound  Saturn Awards  instance of  Best Special Visual Effects  Saturn Awards  instance of  Best Director  Saturn Awards  instance of  Best Science Fiction Film  Saturn Awards  instance of
# Raw extraction output:  The Matrix  National Film Registry  award received  The Matrix Reloaded  followed by  National Film Registry  Library of Congress  parent organization  Library of Congress  National Film Registry  subsidiary  The Matrix Reloaded  The Matrix  follows  The Matrix Revolutions  followed by  The Matrix Revolutions  The Matrix Reloaded  follows
# Raw extraction output:  The Animatrix  anthology film  instance of
# Raw extraction output:  The Matrix Resurrections  Lana Wachowski  director
# Raw extraction output:  Morpheus  Trinity  spouse  Trinity  Morpheus  spouse  Morpheus  spouse  Morpheus  Trinity  spouse
# Raw extraction output:  Neo  Matrix  present in work  Matrix  Neo  characters  Neo  characters  Neo  Matrix  present in work
# Raw extraction output:  Nebuchadnezzar  hovercraft  instance of
# Raw extraction output:  The Matrix  simulated reality  instance of
# Raw extraction output:  Morpheus  Agents  member of  Agents  Morpheus  has part
# Raw extraction output:  Morpheus  Neo  student  Neo  Morpheus  student of  Morpheus  student of  Morpheus  Neo  student  Neo  student  Neo  Morpheus  student of  Morpheus  student of
# Raw extraction output:  Morpheus  Matrix  present in work
# Raw extraction output:  Morpheus  Trinity  present in work  Trinity  Morpheus  characters  Morpheus  characters  Morpheus  characters  Morpheus  Trinity  present in work  Trinity  present in work  Morpheus  Trinity  present in work  Trinity  present in work
# Raw extraction output:  Neo  the Matrix  present in work  the Matrix  Neo  characters  Neo  characters  Neo  characters  Neo  the Matrix  present in work  Neo  the Matrix  present in work
# Raw extraction output:  Neo  Keanu Reeves  performer
# Raw extraction output:  Wild Wild West  Will Smith  cast member
# Raw extraction output:  Titanic  Leonardo DiCaprio  cast member
# Raw extraction output:  Morpheus  Laurence Fishburne  performer
# Raw extraction output:  Morpheus  Neil Gaiman  creator  Sandman  present in work  Neil Gaiman  Sandman  notable work  Sandman  Morpheus  characters  Neil Gaiman  author
# Raw extraction output:  the Wachowskis  storyboard  field of work
# Raw extraction output:  Neo  The Matrix  present in work  Sandra Bullock  performer
# Raw extraction output:  Niobe  Jada Pinkett Smith  performer
# Raw extraction output:  Wachowskis  robotic  genre
# Raw extraction output:  Cypher  Joe Pantoliano  performer
# Raw extraction output:  Bound  1996  publication date
# Raw extraction output:  The Oracle  Gloria Foster  performer
# Raw extraction output:  White Rabbit  Alice's Adventures in Wonderland  present in work  Alice's Adventures in Wonderland  White Rabbit  characters
# Raw extraction output:  Bound  Lorenzo di Bonaventura  producer
# Raw extraction output:  Morpheus  Val Kilmer  performer
# Raw extraction output:  Wild Wild West  Joel Silver  producer
# Raw extraction output:  The Matrix  Warner Bros.  production company  Village Roadshow Pictures  production company
# Raw extraction output:  Jean Baudrillard  Simulacra and Simulation  notable work  Simulacra and Simulation  Jean Baudrillard  author
# Raw extraction output:  Kevin Kelly  Out of Control: The New Biology of Machines, Social Systems, and the Economic World  notable work  Out of Control: The New Biology of Machines, Social Systems, and the Economic World  Kevin Kelly  author
# Raw extraction output:  Yuen Woo-ping  film director  occupation
# Raw extraction output:  Reeves  Fishburne  sibling  Fishburne  Reeves  sibling
# Raw extraction output:  cervical  spine  part of  spine  cervical  has part
# Raw extraction output:  Fox Studios  Sydney  headquarters location
# Raw extraction output:  Thomas Anderson  Culver Studios  employer
# Raw extraction output:  Martin Place  Sydney  located in the administrative territorial entity
# Raw extraction output:  Kent Street  Sussex Street  connects with  Sussex Street  Kent Street  connects with
# Raw extraction output:  the lobby scene  Moss  cast member
# Raw extraction output:  double kick  triple kick  has part  triple kick  double kick  part of
# Raw extraction output:  subway station  subway  part of
# Raw extraction output:  Chad Stahelski  stunt double  occupation
# Raw extraction output:  Neo  Reeves  performer  Neo  Reeves  performer
# Raw extraction output:  The Art of the Matrix  Dane A. Davis  director
# Raw extraction output:  The Matrix  Don Davis  composer
# Raw extraction output:  Morpheus  glasses  uses  glasses  Morpheus  used by
# Raw extraction output:  contrapuntal  score  part of
# Raw extraction output:  Rob Dougan  Rage Against the Machine  member of  Rage Against the Machine  Rob Dougan  has part
# Raw extraction output:  kana  Japan  country of origin
# Raw extraction output:  Ghost in the Shell  1995  publication date
# Raw extraction output:  Owen Paterson  production designer  occupation
# Raw extraction output:  green color  blue  opposite of  blue  green color  opposite of
# Raw extraction output:  Nebuchadnezzar  Star Trek  present in work
# Raw extraction output:  Neo  Matrix  present in work  Matrix  Neo  characters
# Raw extraction output:  Kym Barrett  costume designer  occupation
# Raw extraction output:  Trinity  martial art  genre  Trinity  martial art  genre  Trinity  martial art  genre
# Raw extraction output:  Akira  Otomo Katsuhiro  director
# Raw extraction output:  view-morphing  still camera  subclass of
# Raw extraction output:  bullet time  visual effect  instance of
# Raw extraction output:  screenplay for the film  The Wachowskis  screenwriter
# Raw extraction output:  John Gaeta  effects producer  occupation
# Raw extraction output:  frame  still picture  part of
# Raw extraction output:  super slow-motion  slow-motion  subclass of
# Raw extraction output:  edit out  computer technology  facet of
# Raw extraction output:  George Borshukov  3D models  field of work
# Raw extraction output:  Unix-like  operating system  subclass of  FreeBSD  Unix-like  subclass of
# Raw extraction output:  effects  digitally  subclass of
# Raw extraction output:  The Matrix Reloaded  The Matrix Revolutions  followed by  The Matrix Revolutions  The Matrix Reloaded  follows
# Raw extraction output:  Universal Capture  3D models  use
# Raw extraction output:  The Matrix  September 21, 1999  publication date  Warner Home Video  distributed by
# Raw extraction output:  VHS  DVD  followed by  DVD  VHS  follows
# Raw extraction output:  The Ultimate Matrix Collection  HD DVD  platform  May 22, 2007  publication date  Blu-ray  platform
# Raw extraction output:  The Complete Matrix Trilogy  2010  publication date
# Raw extraction output:  Enter the Matrix  The Matrix Reloaded  followed by  The Matrix Reloaded  Enter the Matrix  follows  The Matrix Online  MMORPG  genre  Epic Games  developer  Epic Games  Unreal Engine 5  owner of  Unreal Engine 5  Epic Games  developer
# Raw extraction output:  The Matrix  Lost in Space  follows  Indecent Proposal  follows  Lost in Space  The Matrix  followed by  Indecent Proposal  The Matrix  followed by
# Raw extraction output:  Speed  Keanu Reeves  cast member  1994  publication date
# Raw extraction output:  Forces of Nature  10 Things I Hate About You  followed by  10 Things I Hate About You  Forces of Nature  follows  The Out-of-Towners  followed by  The Out-of-Towners  10 Things I Hate About You  follows
# Raw extraction output:  Entrapment  Warner Bros.  distributed by
# Raw extraction output:  fifth highest-grossing film of 1999  1999  point in time
# Raw extraction output:  fourth-highest-grossing film of the year  The Sixth Sense  has part  Toy Story 2  has part  The Sixth Sense  fourth-highest-grossing film of the year  part of the series  Toy Story 2  fourth-highest-grossing film of the year  part of the series
# Raw extraction output:  list of highest-grossing films of all time  2012  point in time  The Matrix  Matrix franchise  part of the series  Matrix franchise  The Matrix  has part  The Matrix Reloaded  has part  The Matrix Reloaded  Matrix franchise  part of the series
# Raw extraction output:  Rotten Tomatoes  review aggregator  instance of
# Raw extraction output:  critical consensus  Metacritic  publisher
# Raw extraction output:  Sight & Sound  Philip Strick  editor
# Raw extraction output:  production design  cinematography  part of
# Raw extraction output:  Jonathan Rosenbaum  Chicago Reader  employer
# Raw extraction output:  Ian Nathan  Empire  employer
# Raw extraction output:  Maitland McDonagh  TV Guide  employer
# Raw extraction output:  dystopian  sci-fi  subclass of
# Raw extraction output:  Andrew O'Hehir  Salon  employer
# Raw extraction output:  Bound  Wachowskis  production company
# Raw extraction output:  The Matrix  science fiction  genre
# Raw extraction output:  William Gibson  cyberpunk fiction  genre
# Raw extraction output:  The Matrix  M. Night Shyamalan  director
# Raw extraction output:  The Matrix  Quentin Tarantino  director  The Matrix  Quentin Tarantino  director
# Raw extraction output:  The Matrix  Best Film Editing  award received  Best Sound Editing  award received  Best Visual Effects  award received  Best Sound  award received  Best Film Editing  Academy Awards  instance of  Best Sound Editing  Academy Awards  instance of  Best Visual Effects  Academy Awards  instance of  Best Sound  Academy Awards  instance of
# Raw extraction output:  Best Science Fiction Film  Saturn Awards  part of  Best Direction  Saturn Awards  part of
# Raw extraction output:  Buddhism  religion  instance of  Judaism  religion  instance of
# Raw extraction output:  Welcome to Paradox  SYFY Channel  original broadcaster
# Raw extraction output:  World on a Wire  Rainer Werner Fassbinders  creator  1973  publication date  Simulacron-3  based on  Simulacron-3  World on a Wire  derivative work
# Raw extraction output:  device  Doctor Who  present in work
# Raw extraction output:  The Deadly Assassin  1976  publication date
# Raw extraction output:  Fist of Legend  1995  publication date  Jet Li  cast member
# Raw extraction output:  Mamoru Oshii  Ghost in the Shell  notable work  Ghost in the Shell  Mamoru Oshii  director
# Raw extraction output:  Lewis Carroll  Alice's Adventures in Wonderland  notable work  Alice's Adventures in Wonderland  Lewis Carroll  author
# Raw extraction output:  cyberpunk  science fiction  subclass of  Neuromancer  cyberpunk  genre  William Gibson  author  William Gibson  Neuromancer  notable work
# Raw extraction output:  The White Room  1969  publication date
# Raw extraction output:  speculative Exegesis  Philip K. Dick  author
# Raw extraction output:  The Matrix  Philip K. Dick  after a work by
# Raw extraction output:  Jean Baudrillard  Simulacra and Simulation  notable work  Simulacra and Simulation  Jean Baudrillard  author
# Raw extraction output:  The Matrixial Gaze  Bracha L.  creator  Bracha L.  The Matrixial Gaze  notable work
# Raw extraction output:  Heinz-Peter Schwerfel  film theorists  field of work
# Raw extraction output:  Out of Control: The New Biology of Machines, Social Systems, and the Economic World  Kevin Kelly  author
# Raw extraction output:  Allegory of the Cave  Plato  author
# Raw extraction output:  Plato  theory of Forms  notable work  theory of Forms  Plato  discoverer or inventor
# Raw extraction output:  Critique of Pure Reason  Kant  author
# Raw extraction output:  Agent Smith  Matrix  present in work  Matrix  Agent Smith  characters
# Raw extraction output:  world in 1999  1999  point in time
# Raw extraction output:  Christianity  Christ  named after
# Raw extraction output:  Trinity  Christianity  facet of
# Raw extraction output:  Morpheus  The Matrix  present in work  Zhuangzi  Taoist  movement  Neo  The Matrix  present in work  The Matrix  Morpheus  characters  Neo  characters  Neo  characters  Neo  The Matrix  present in work
# Raw extraction output:  Lilly Wachowski  GLAAD Media Awards  award received
# Raw extraction output:  The Matrix  gender transition  main subject
# Raw extraction output:  bullet time effect  slow motion  subclass of
# Raw extraction output:  Max Payne  video game  instance of  Superhot  video game  instance of
# Raw extraction output:  Marx Reloaded  Neo  characters  Morpheus  characters  Neo  Marx Reloaded  present in work  Morpheus  Marx Reloaded  present in work
# Raw extraction output:  Charlie's Angels  Cameron Diaz  cast member  Equilibrium  Christian Bale  cast member  Night Watch  Timur Bekmambetov  director  Wanted  Timur Bekmambetov  director
# Raw extraction output:  Tron  The Matrix  derivative work  The Matrix  Tron  based on  Tron  based on  Tron  based on  Tron  The Matrix  derivative work  The Matrix  derivative work  Awara Paagal Deewana  2002  publication date
# Raw extraction output:  wire fu  Hong Kong action cinema  subclass of
# Raw extraction output:  Yuen Woo-ping  Yuen Cheung-yan  sibling  Yuen Cheung-yan  Yuen Woo-ping  sibling
# Raw extraction output:  The Matrix  Chad Stahelski  director  The Matrix  Chad Stahelski  director  The Matrix  Chad Stahelski  director
# Raw extraction output:  The Matrix  Carrie-Anne Moss  cast member
# Raw extraction output:  Matrix trilogy  trilogies  instance of  Star Wars prequels  trilogies  instance of
# Raw extraction output:  Stephen Dowling  BBC  employer
# Raw extraction output:  Encyclopedia of Superheroes on Film and Television  John Kenneth Muir  author
# Raw extraction output:  100 Years...100 Thrills  American Film Institute  conferred by
# Raw extraction output:  The 500 Greatest Movies of All Time  Empire  published in
# Raw extraction output:  National Film Registry  Library of Congress  parent organization  Library of Congress  National Film Registry  subsidiary
# Raw extraction output:  The Matrix Reloaded  The Matrix Revolutions  followed by  The Matrix Revolutions  The Matrix Reloaded  follows
# Raw extraction output:  2003  2003  point in time
# Raw extraction output:  bullet time  visual effects  subclass of
# Raw extraction output:  The Animatrix  Zak Penn  screenwriter
# Raw extraction output:  Matrix film  Keanu Reeves  cast member  Carrie-Anne Moss  cast member  Neo  Matrix film  present in work  Keanu Reeves  performer  Trinity  Matrix film  present in work  Carrie-Anne Moss  performer
# Raw extraction output:  The Deadly Assassin  Doctor Who  part of the series
# Raw extraction output:  The Matrix Unlocked: An Unauthorized Review of the Matrix Phenomenon  Contender Books  publisher
# Raw extraction output:  Nerd Do Well  Simon  author
# Raw extraction output:  The Matrix  The Matrix Was a Documentary  has part  The Matrix  The Matrix Was a Documentary  has part  The Matrix  The Matrix Was a Documentary  has part  The Matrix  The Matrix Was a Documentary  has part
#
# Filtered Triples for 'The Matrix':
# ('The Matrix', 'part of the series', 'Matrix film series')
# ('The Matrix', 'publication date', 'March 31, 1999')
# ('The Matrix', 'award received', 'National Film Registry')
# ('The Matrix Resurrections', 'director', 'Lana Wachowski')
# ('The Matrix', 'instance of', 'simulated reality')
# ('Neo', 'present in work', 'the Matrix')
# ('Neo', 'present in work', 'The Matrix')
# ('The Matrix', 'production company', 'Warner Bros.')
# ('The Art of the Matrix', 'director', 'Dane A. Davis')
# ('The Matrix', 'composer', 'Don Davis')
# ('The Matrix Reloaded', 'followed by', 'The Matrix Revolutions')
# ('The Matrix', 'publication date', 'September 21, 1999')
# ('VHS', 'followed by', 'DVD')
# ('Enter the Matrix', 'followed by', 'The Matrix Reloaded')
# ('The Matrix', 'follows', 'Lost in Space')
# ('Forces of Nature', 'followed by', '10 Things I Hate About You')
# ('The Matrix', 'genre', 'science fiction')
# ('The Matrix', 'director', 'M. Night Shyamalan')
# ('The Matrix', 'director', 'Quentin Tarantino')
# ('The Matrix', 'award received', 'Best Film Editing')
# ('The Matrix', 'after a work by', 'Philip K. Dick')
# ('The Matrixial Gaze', 'creator', 'Bracha L.')
# ('Morpheus', 'present in work', 'The Matrix')
# ('The Matrix', 'main subject', 'gender transition')
# ('Tron', 'derivative work', 'The Matrix')
# ('The Matrix', 'director', 'Chad Stahelski')
# ('The Matrix', 'cast member', 'Carrie-Anne Moss')
# ('The Matrix Reloaded', 'followed by', 'The Matrix Revolutions')
# ('The Matrix Unlocked: An Unauthorized Review of the Matrix Phenomenon', 'publisher', 'Contender Books')
# ('The Matrix', 'has part', 'The Matrix Was a Documentary')
# Triple: ('The Matrix', 'part of the series', 'Matrix film series')
# Triple: ('The Matrix', 'publication date', 'March 31, 1999')
# Triple: ('The Matrix', 'award received', 'National Film Registry')
# Triple: ('The Matrix Resurrections', 'director', 'Lana Wachowski')
# Triple: ('The Matrix', 'instance of', 'simulated reality')
# Triple: ('Neo', 'present in work', 'the Matrix')
# Triple: ('Neo', 'present in work', 'The Matrix')
# Triple: ('The Matrix', 'production company', 'Warner Bros.')
# Triple: ('The Art of the Matrix', 'director', 'Dane A. Davis')
# Triple: ('The Matrix', 'composer', 'Don Davis')
# Triple: ('The Matrix Reloaded', 'followed by', 'The Matrix Revolutions')
# Triple: ('The Matrix', 'publication date', 'September 21, 1999')
# Triple: ('VHS', 'followed by', 'DVD')
# Triple: ('Enter the Matrix', 'followed by', 'The Matrix Reloaded')
# Triple: ('The Matrix', 'follows', 'Lost in Space')
# Triple: ('Forces of Nature', 'followed by', '10 Things I Hate About You')
# Triple: ('The Matrix', 'genre', 'science fiction')
# Triple: ('The Matrix', 'director', 'M. Night Shyamalan')
# Triple: ('The Matrix', 'director', 'Quentin Tarantino')
# Triple: ('The Matrix', 'award received', 'Best Film Editing')
# Triple: ('The Matrix', 'after a work by', 'Philip K. Dick')
# Triple: ('The Matrixial Gaze', 'creator', 'Bracha L.')
# Triple: ('Morpheus', 'present in work', 'The Matrix')
# Triple: ('The Matrix', 'main subject', 'gender transition')
# Triple: ('Tron', 'derivative work', 'The Matrix')
# Triple: ('The Matrix', 'director', 'Chad Stahelski')
# Triple: ('The Matrix', 'cast member', 'Carrie-Anne Moss')
# Triple: ('The Matrix Reloaded', 'followed by', 'The Matrix Revolutions')
# Triple: ('The Matrix Unlocked: An Unauthorized Review of the Matrix Phenomenon', 'publisher', 'Contender Books')
# Triple: ('The Matrix', 'has part', 'The Matrix Was a Documentary')

# %%
import re
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import networkx as nx
import matplotlib.pyplot as plt
import requests
from rdflib import Graph, Namespace, URIRef

# Charger le modèle REBEL
model_name = "Babelscape/rebel-large"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)


def get_wikipedia_summary(title, year=-1, language="en"):
    """
    Récupère le résumé d'un article Wikipédia ou sélectionne une sous-page pertinente.
    :param title: Titre de la page Wikipédia.
    :param year: Année associée au film (par défaut -1 pour ignorer).
    :param language: Langue de l'article (par défaut "en").
    :return: Résumé textuel de l'article.
    """
    url = f"https://{language}.wikipedia.org/w/api.php"
    params = {
        "action": "query",
        "format": "json",
        "titles": title,
        "prop": "extracts",
        "explaintext": True,
        "redirects": 1  # Suivre les redirections
    }

    response = requests.get(url, params=params)
    if response.status_code == 200:
        data = response.json()
        page = next(iter(data["query"]["pages"].values()))

        # Cas où la page contient "may refer to"
        if "extract" in page and "may refer to" in page["extract"]:
            # Extraire les sous-pages mentionnées dans la section
            subpages = re.findall(r"(?<=\n)Frozen \((.*?)\)", page["extract"])
            if year != -1:
                # Filtrer les sous-pages contenant l'année
                matching_pages = [sp for sp in subpages if str(year) in sp]
                if matching_pages:
                    print(f"Correspondance trouvée : Frozen ({matching_pages[0]})")
                    return get_wikipedia_summary(f"Frozen ({matching_pages[0]})", language=language)
            # Si aucune correspondance avec l'année, choisir la première sous-page
            if subpages:
                print(f"Aucune année précise trouvée. Sélection de : Frozen ({subpages[0]})")
                return get_wikipedia_summary(f"Frozen ({subpages[0]})", language=language)
            else:
                print("Aucune sous-page identifiable.")
                return None

        # Retourner le résumé de la page normale
        if "extract" in page:
            return page["extract"]
        else:
            print(f"Aucun résumé trouvé pour le titre '{title}'.")
            return None
    else:
        print(f"Erreur lors de la requête : {response.status_code}")
        return None



def split_text(text, max_length=512):
    sentences = text.split(". ")
    blocks = []
    current_block = ""
    for sentence in sentences:
        if len(current_block) + len(sentence) <= max_length:
            current_block += sentence + ". "
        else:
            blocks.append(current_block.strip())
            current_block = sentence + ". "
    if current_block:
        blocks.append(current_block.strip())
    return blocks


def extract_entities_and_relations(block):
    inputs = tokenizer(block, return_tensors="pt", truncation=True, max_length=512)
    outputs = model.generate(**inputs)
    decoded_output = tokenizer.batch_decode(outputs, skip_special_tokens=True)
    return decoded_output[0]


def parse_rebel_output(output):
    triples = []
    statements = output.split('\n')
    for statement in statements:
        parts = statement.split('  ')
        if len(parts) >= 3:
            subject = parts[0].strip()
            obj = parts[1].strip()
            relation = parts[2].strip()
            if subject and obj and relation:
                triples.append((subject, relation, obj))
    return triples


def filter_triples(triples, title, relevant_relations=None):
    if relevant_relations is None:
        relevant_relations = ["followed by", "follows"]
    filtered = []
    for triple in triples:
        subject, relation, obj = triple
        if title.lower() in subject.lower() or title.lower() in obj.lower() or relation.lower() in relevant_relations:
            filtered.append(triple)
    return filtered


def create_graph(triples):
    graph = nx.DiGraph()
    for triple in triples:
        if len(triple) == 3 and all(triple):
            subject, relation, obj = triple
            graph.add_node(subject)
            graph.add_node(obj)
            graph.add_edge(subject, obj, label=relation)
    return graph


def plot_graph(graph, title):
    plt.figure(figsize=(12, 8))
    if len(graph) == 0:
        return
    pos = nx.kamada_kawai_layout(graph)
    nx.draw_networkx_nodes(graph, pos, node_color="lightblue", node_size=3000)
    nx.draw_networkx_labels(graph, pos, font_size=10, font_weight="bold")
    nx.draw_networkx_edges(graph, pos)
    edge_labels = nx.get_edge_attributes(graph, 'label')
    nx.draw_networkx_edge_labels(graph, pos, edge_labels=edge_labels)
    plt.title(f"Knowledge Graph for '{title}'")
    plt.axis('off')
    plt.tight_layout()
    plt.show()


def save_as_rdf(triples, filename="knowledge_graph.ttl"):
    g = Graph()
    ex = Namespace("http://example.org/")
    g.bind("ex", ex)

    for subject, relation, obj in triples:
        g.add((URIRef(ex[subject]), URIRef(ex[relation]), URIRef(ex[obj])))

    g.serialize(destination=filename, format="turtle")
    print(f"Graph saved as RDF in {filename}")


# Liste élargie de films
film_titles = [
    "Ralph Breaks the Internet",
    "Frozen",
    "Inception",
    "The Matrix",
    "The Lion King",
    "Toy Story",
    "Avengers: Endgame",
    "Harry Potter and the Philosopher's Stone",
    "The Lord of the Rings: The Fellowship of the Ring",
    "Spider-Man: No Way Home"
]

all_triples = []

for title in film_titles:
    print(f"\nTraitement du film : {title}")
    text = get_wikipedia_summary(title, language="en")
    
    if text:
        text_blocks = split_text(text)
        triples = []

        for block in text_blocks:
            result = extract_entities_and_relations(block)
            block_triples = parse_rebel_output(result)
            triples.extend(block_triples)

        # Filtrer les triples pour garder uniquement ceux pertinents
        filtered_triples = filter_triples(triples, title, relevant_relations=["followed by", "follows"])
        all_triples.extend(filtered_triples)

        # Créer et afficher le graphe
        knowledge_graph = create_graph(filtered_triples)
        plot_graph(knowledge_graph, title)
    else:
        print(f"Pas de données trouvées pour '{title}'.")

# Enregistrer les triples en RDF
save_as_rdf(all_triples, filename="movies_knowledge_graph.ttl")
# Out:
# Traitement du film : Ralph Breaks the Internet
# Traitement du film : Frozen
# Aucune année précise trouvée. Sélection de : Frozen (1997 film)
# Traitement du film : Inception
# Traitement du film : The Matrix
# Traitement du film : The Lion King
